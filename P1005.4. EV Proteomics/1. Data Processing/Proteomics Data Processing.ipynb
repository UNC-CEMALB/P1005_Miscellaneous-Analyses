# %%
Output = ('/Users/alexis/Library/CloudStorage/OneDrive-UniversityofNorthCarolinaatChapelHill/CEMALB_DataAnalysisPM/Projects/P1005. Miscellaneous Analyses/P1005.7. EV Proteomics/P1005.7.3. Analyses/P1005.7.3.1. Data Processing')
cur_date = "013124"

library(readxl)
library(openxlsx)
library(tidyverse)
library(imputeLCMD)
library(factoextra)
library(vegan)
library(preprocessCore)

# reading in files
proteome_df = data.frame(read_excel("Input/EV_function_proteomics_012924.xlsx")) %>%
    rename(Protein = Accession, Unique_Peptides = Number_of_UniquePeptides)

# for some reason this col was read in as a character not numeric
proteome_df$PFAS.CEV_R2 = as.numeric(proteome_df$PFAS.CEV_R2)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Loading required package: tmvtnorm
#
# Loading required package: mvtnorm
#
# Loading required package: Matrix
#
#
# Attaching package: ‘Matrix’
#
#
# The following objects are masked from ‘package:tidyr’:
#
#     expand, pack, unpack
#
#
# Loading required package: stats4
#
# Loading required package: gmm
#
# Loading required package: sandwich
#
# Loading required package: norm
#
# This package has some major limitations
# (for example, it does not work reliably when
# the number of variables exceeds 30),
# and has been superseded by the norm2 package.
#
# Loading required package: pcaMethods
#
# Loading required package: Biobase
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:lubridate’:
#
#     intersect, setdiff, union
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘pcaMethods’
#
#
# The following object is masked from ‘package:stats’:
#
#     loadings
#
#
# Loading required package: impute
#
# Welcome! Want to learn more? See two factoextra-related books at https://goo.gl/ve3WBa
#
# Loading required package: permute
#
# Loading required package: lattice
#
# This is vegan 2.6-4
#
#
# Attaching package: ‘vegan’
#
#
# The following object is masked from ‘package:pcaMethods’:
#
#     scores
#
#
# Warning message:
# “Coercing text to numeric in U1159 / R1159C21: 'NaN'”
# Warning message:
# “Coercing text to numeric in V1159 / R1159C22: 'NaN'”
# Warning message:
# “Coercing text to numeric in W1159 / R1159C23: 'NaN'”
# Warning message:
# “Coercing text to numeric in X1159 / R1159C24: 'NaN'”
# Warning message:
# “Coercing text to numeric in Y1159 / R1159C25: 'NaN'”
# Warning message:
# “Coercing text to numeric in Z1159 / R1159C26: 'NaN'”
# Warning message:
# “Coercing text to numeric in AA1159 / R1159C27: 'NaN'”
# Warning message:
# “Coercing text to numeric in AC1159 / R1159C29: 'NaN'”
# Warning message:
# “Coercing text to numeric in AD1159 / R1159C30: 'NaN'”
# Warning message:
# “Coercing text to numeric in AE1159 / R1159C31: 'NaN'”
# Warning message:
# “Coercing text to numeric in AG1159 / R1159C33: 'NaN'”
# Warning message:
# “Coercing text to numeric in AH1159 / R1159C34: 'NaN'”
# Warning message:
# “Coercing text to numeric in AI1159 / R1159C35: 'NaN'”
# Warning message:
# “Coercing text to numeric in AJ1159 / R1159C36: 'NaN'”
# Warning message:
# “Coercing text to numeric in AL1159 / R1159C38: 'NaN'”
# Warning message:
# “Coercing text to numeric in AL1163 / R1163C38: 'NaN'”
# Warning message:
# “Coercing text to numeric in H1306 / R1306C8: 'NaN'”
# Warning message:
# “Coercing text to numeric in AF1319 / R1319C32: 'NaN'”
# Warning message:
# “Coercing text to numeric in T1558 / R1558C20: 'NaN'”
# Warning message:
# “Coercing text to numeric in AE1558 / R1558C31: 'NaN'”
# Warning message:
# “Coercing text to numeric in Z1729 / R1729C26: 'NaN'”
# Warning message:
# “Coercing text to numeric in AA1729 / R1729C27: 'NaN'”
# Warning message:
# “Coercing text to numeric in AC1729 / R1729C29: 'NaN'”
# Warning message:
# “Coercing text to numeric in AG1729 / R1729C33: 'NaN'”
# Warning message:
# “Coercing text to numeric in AA2164 / R2164C27: 'NaN'”
# Warning message:
# “Coercing text to numeric in E2248 / R2248C5: 'NaN'”
# Warning message:
# “Coercing text to numeric in Q2329 / R2329C17: 'NaN'”
# Warning message:
# “Coercing text to numeric in V2531 / R2531C22: 'NaN'”
# Warning message:
# “Coercing text to numeric in W2531 / R2531C23: 'NaN'”
# Warning message:
# “Coercing text to numeric in Y2531 / R2531C25: 'NaN'”
# Warning message:
# “Coercing text to numeric in Z2531 / R2531C26: 'NaN'”
# Warning message:
# “Coercing text to numeric in AA2531 / R2531C27: 'NaN'”
# Warning message:
# “Coercing text to numeric in AC2531 / R2531C29: 'NaN'”
# Warning message:
# “Coercing text to numeric in AD2531 / R2531C30: 'NaN'”
# Warning message:
# “Coercing text to numeric in AE2531 / R2531C31: 'NaN'”
# Warning message:
# “Coercing text to numeric in AF2531 / R2531C32: 'NaN'”
# Warning message:
# “Coercing text to numeric in AG2531 / R2531C33: 'NaN'”
# Warning message:
# “Coercing text to numeric in AH2531 / R2531C34: 'NaN'”
# Warning message:
# “Coercing text to numeric in AK2531 / R2531C37: 'NaN'”
# Warning message:
# “Coercing text to numeric in AL2531 / R2531C38: 'NaN'”
# Warning message:
# “Coercing text to numeric in C2935 / R2935C3: 'NaN'”
# Warning message:
# “Coercing text to numeric in D2935 / R2935C4: 'NaN'”
# Warning message:
# “Coercing text to numeric in J2935 / R2935C10: 'NaN'”
# Warning message:
# “Coercing text to numeric in D2978 / R2978C4: 'NaN'”
# Warning message:
# “Coercing text to numeric in J2978 / R2978C10: 'NaN'”
# Warning message:
# “Coercing text to numeric in N2978 / R2978C14: 'NaN'”
# Warning message:
# “Coercing text to numeric in Q2978 / R2978C17: 'NaN'”
# Warning message:
# “Coercing text to numeric in T2978 / R2978C20: 'NaN'”
# Warning message:
# “Coercing text to numeric in C3252 / R3252C3: 'NaN'”
# Warning message:
# “Coercing text to numeric in D3252 / R3252C4: 'NaN'”
# Warning message:
# “Coercing text to numeric in E3252 / R3252C5: 'NaN'”
# Warning message:
# “Coercing text to numeric in G3252 / R3252C7: 'NaN'”
# Warning message:
# “Coercing text to numeric in H3252 / R3252C8: 'NaN'”
# Warning message:
# “Coercing text to numeric in I3252 / R3252C9: 'NaN'”
# Warning message:
# “Coercing text to numeric in J3252 / R3252C10: 'NaN'”
# Warning message:
# “Coercing text to numeric in K3252 / R3252C11: 'NaN'”
# Warning message:
# “Coercing text to numeric in L3252 / R3252C12: 'NaN'”
# Warning message:
# “Coercing text to numeric in M3252 / R3252C13: 'NaN'”
# Warning message:
# “Coercing text to numeric in O3252 / R3252C15: 'NaN'”
# Warning message:
# “Coercing text to numeric in Q3252 / R3252C17: 'NaN'”
# Warning message:
# “Coercing text to numeric in T3252 / R3252C20: 'NaN'”
# Warning message:
# “Coercing text to numeric in V3252 / R3252C22: 'NaN'”
# Warning message:
# “Coercing text to numeric in W3252 / R3252C23: 'NaN'”
# Warning message:
# “Coercing text to numeric in X3252 / R3252C24: 'NaN'”
# Warning message:
# “Coercing text to numeric in Y3252 / R3252C25: 'NaN'”
# Warning message:
# “Coercing text to numeric in Z3252 / R3252C26: 'NaN'”
# Warning message:
# “Coercing text to numeric in AA3252 / R3252C27: 'NaN'”
# Warning message:
# “Coercing text to numeric in AC3252 / R3252C29: 'NaN'”
# Warning message:
# “Coercing text to numeric in AD3252 / R3252C30: 'NaN'”
# Warning message:
# “Coercing text to numeric in AE3252 / R3252C31: 'NaN'”
# Warning message:
# “Coercing text to numeric in AF3252 / R3252C32: 'NaN'”
# Warning message:
# “Coercing text to numeric in AG3252 / R3252C33: 'NaN'”
# Warning message:
# “Coercing text to numeric in AH3252 / R3252C34: 'NaN'”
# Warning message:
# “Coercing text to numeric in AI3252 / R3252C35: 'NaN'”
# Warning message:
# “Coercing text to numeric in AK3252 / R3252C37: 'NaN'”
# Warning message:
# “Coercing text to numeric in AL3252 / R3252C38: 'NaN'”
# Warning message:
# “Coercing text to numeric in Y3385 / R3385C25: 'NaN'”
# Warning message:
# “Coercing text to numeric in AA3385 / R3385C27: 'NaN'”
# Warning message:
# “Coercing text to numeric in AF3385 / R3385C32: 'NaN'”
# Warning message:
# “Coercing text to numeric in AH3385 / R3385C34: 'NaN'”
# Warning message:
# “Coercing text to numeric in AI3385 / R3385C35: 'NaN'”
# Warning message:
# “Coercing text to numeric in AA3601 / R3601C27: 'NaN'”
# Warning message:
# “Coercing text to numeric in I3604 / R3604C9: 'NaN'”
# Warning message:
# “Coercing text to numeric in Z3694 / R3694C26: 'NaN'”
# Warning message:
# “Coercing text to numeric in AC3694 / R3694C29: 'NaN'”
# Warning message:
# “Coercing text to numeric in AD3694 / R3694C30: 'NaN'”
# Warning message:
# “Coercing text to numeric in AH3694 / R3694C34: 'NaN'”
# Warning message:
# “Coercing text to numeric in AJ3694 / R3694C36: 'NaN'”
# Warning message:
# “Coercing text to numeric in I3703 / R3703C9: 'NaN'”
# Warning message:
# “Coercing text to numeric
19: 'NaN'”
# Warning message:
# “Coercing text to numeric in T7099 / R7099C20: 'NaN'”
# Warning message:
# “Coercing text to numeric in U7099 / R7099C21: 'NaN'”
# Warning message:
# “Coercing text to numeric in V7099 / R7099C22: 'NaN'”
# Warning message:
# “Coercing text to numeric in W7099 / R7099C23: 'NaN'”
# Warning message:
# “Coercing text to numeric in X7099 / R7099C24: 'NaN'”
# Warning message:
# “Coercing text to numeric in Y7099 / R7099C25: 'NaN'”
# Warning message:
# “Coercing text to numeric in Z7099 / R7099C26: 'NaN'”
# Warning message:
# “Coercing text to numeric in AA7099 / R7099C27: 'NaN'”
# Warning message:
# “Coercing text to numeric in AC7099 / R7099C29: 'NaN'”
# Warning message:
# “Coercing text to numeric in AD7099 / R7099C30: 'NaN'”
# Warning message:
# “Coercing text to numeric in AE7099 / R7099C31: 'NaN'”
# Warning message:
# “Coercing text to numeric in AF7099 / R7099C32: 'NaN'”
# Warning message:
# “Coercing text to numeric in AG7099 / R7099C33: 'NaN'”
# Warning message:
# “Coercing text to numeric in AH7099 / R7099C34: 'NaN'”
# Warning message:
# “Coercing text to numeric in AI7099 / R7099C35: 'NaN'”
# Warning message:
# “Coercing text to numeric in AJ7099 / R7099C36: 'NaN'”
# Warning message:
# “Coercing text to numeric in AK7099 / R7099C37: 'NaN'”
# Warning message:
# “Coercing text to numeric in AL7099 / R7099C38: 'NaN'”
# Warning message:
# “Coercing text to numeric in L7100 / R7100C12: 'NaN'”
# Warning message:
# “Coercing text to numeric in R7100 / R7100C18: 'NaN'”
# Warning message:
# “Coercing text to numeric in Y7100 / R7100C25: 'NaN'”
# Warning message:
# “Coercing text to numeric in Z7100 / R7100C26: 'NaN'”
# Warning message:
# “Coercing text to numeric in AA7100 / R7100C27: 'NaN'”
# Warning message:
# “Coercing text to numeric in AC7100 / R7100C29: 'NaN'”
# Warning message:
# “Coercing text to numeric in AD7100 / R7100C30: 'NaN'”
# Warning message:
# “Coercing text to numeric in AE7100 / R7100C31: 'NaN'”
# Warning message:
# “Coercing text to numeric in AF7100 / R7100C32: 'NaN'”
# Warning message:
# “Coercing text to numeric in AH7100 / R7100C34: 'NaN'”
# Warning message:
# “Coercing text to numeric in AI7100 / R7100C35: 'NaN'”
# Warning message:
# “Coercing text to numeric in AJ7100 / R7100C36: 'NaN'”
# Warning message:
# “Coercing text to numeric in AK7100 / R7100C37: 'NaN'”
# Warning message:
# “Coercing text to numeric in AL7100 / R7100C38: 'NaN'”
# Warning message:
# “Coercing text to numeric in C7101 / R7101C3: 'NaN'”
# Warning message:
# “Coercing text to numeric in D7101 / R7101C4: 'NaN'”
# Warning message:
# “Coercing text to numeric in E7101 / R7101C5: 'NaN'”
# Warning message:
# “Coercing text to numeric in F7101 / R7101C6: 'NaN'”
# Warning message:
# “Coercing text to numeric in G7101 / R7101C7: 'NaN'”
# Warning message:
# “Coercing text to numeric in H7101 / R7101C8: 'NaN'”
# Warning message:
# “Coercing text to numeric in I7101 / R7101C9: 'NaN'”
# Warning message:
# “Coercing text to numeric in J7101 / R7101C10: 'NaN'”
# Warning message:
# “Coercing text to numeric in K7101 / R7101C11: 'NaN'”
# Warning message:
# “Coercing text to numeric in L7101 / R7101C12: 'NaN'”
# Warning message:
# “Coercing text to numeric in N7101 / R7101C14: 'NaN'”
# Warning message:
# “Coercing text to numeric in O7101 / R7101C15: 'NaN'”
# Warning message:
# “Coercing text to numeric in P7101 / R7101C16: 'NaN'”
# Warning message:
# “Coercing text to numeric in Q7101 / R7101C17: 'NaN'”
# Warning message:
# “Coercing text to numeric in S7101 / R7101C19: 'NaN'”
# Warning message:
# “Coercing text to numeric in T7101 / R7101C20: 'NaN'”
# Warning message:
# “Coercing text to numeric in U7101 / R7101C21: 'NaN'”
# Warning message:
# “Coercing text to numeric in V7101 / R7101C22: 'NaN'”
# Warning message:
# “Coercing text to numeric in W7101 / R7101C23: 'NaN'”
# Warning message:
# “Coercing text to numeric in X7101 / R7101C24: 'NaN'”
# Warning message:
# “Coercing text to numeric in Y7101 / R7101C25: 'NaN'”
# Warning message:
# “Coercing text to numeric in Z7101 / R7101C26: 'NaN'”
# Warning message:
# “Coercing text to numeric in AA7101 / R7101C27: 'NaN'”
# Warning message:
# “Coercing text to numeric in AC7101 / R7101C29: 'NaN'”
# Warning message:
# “Coercing text to numeric in AD7101 / R7101C30: 'NaN'”
# Warning message:
# “Coercing text to numeric in AE7101 / R7101C31: 'NaN'”
# Warning message:
# “Coercing text to numeric in AF7101 / R7101C32: 'NaN'”
# Warning message:
# “Coercing text to numeric in AG7101 / R7101C33: 'NaN'”
# Warning message:
# “Coercing text to numeric in AH7101 / R7101C34: 'NaN'”
# Warning message:
# “Coercing text to numeric in AI7101 / R7101C35: 'NaN'”
# Warning message:
# “Coercing text to numeric in AJ7101 / R7101C36: 'NaN'”
# Warning message:
# “Coercing text to numeric in AK7101 / R7101C37: 'NaN'”
# Warning message:
# “Coercing text to numeric in AL7101 / R7101C38: 'NaN'”
# Warning message:
# “Coercing text to numeric in C7102 / R7102C3: 'NaN'”
# Warning message:
# “Coercing text to numeric in D7102 / R7102C4: 'NaN'”
# Warning message:
# “Coercing text to numeric in E7102 / R7102C5: 'NaN'”
# Warning message:
# “Coercing text to numeric in F7102 / R7102C6: 'NaN'”
# Warning message:
# “Coercing text to numeric in G7102 / R7102C7: 'NaN'”
# Warning message:
# “Coercing text to numeric in H7102 / R7102C8: 'NaN'”
# Warning message:
# “Coercing text to numeric in I7102 / R7102C9: 'NaN'”
# Warning message:
# “Coercing text to numeric in J7102 / R7102C10: 'NaN'”
# Warning message:
# “Coercing text to numeric in K7102 / R7102C11: 'NaN'”
# Warning message:
# “Coercing text to numeric in L7102 / R7102C12: 'NaN'”
# Warning message:
# “Coercing text to numeric in N7102 / R7102C14: 'NaN'”
# Warning message:
# “Coercing text to numeric in O7102 / R7102C15: 'NaN'”
# Warning message:
# “Coercing text to numeric in P7102 / R7102C16: 'NaN'”
# Warning message:
# “Coercing text to numeric in Q7102 / R7102C17: 'NaN'”
# Warning message:
# “Coercing text to numeric in R7102 / R7102C18: 'NaN'”
# Warning message:
# “Coercing text to numeric in S7102 / R7102C19: 'NaN'”
# Warning message:
# “Coercing text to numeric in T7102 / R7102C20: 'NaN'”
# Warning message:
# “Coercing text to numeric in U7102 / R7102C21: 'NaN'”
# Warning message:
# “Coercing text to numeric in V7102 / R7102C22: 'NaN'”
# Warning message:
# “Coercing text to numeric in W7102 / R7102C23: 'NaN'”
# Warning message:
# “Coercing text to numeric in X7102 / R7102C24: 'NaN'”
# Warning message:
# “Coercing text to numeric in Y7102 / R7102C25: 'NaN'”
# Warning message:
# “Coercing text to numeric in Z7102 / R7102C26: 'NaN'”
# Warning message:
# “Coercing text to numeric in AA7102 / R7102C27: 'NaN'”
# Warning message:
# “Coercing text to numeric in AC7102 / R7102C29: 'NaN'”
# Warning message:
# “Coercing text to numeric in AD7102 / R7102C30: 'NaN'”
# Warning message:
# “Coercing text to numeric in AE7102 / R7102C31: 'NaN'”
# Warning message:
# “Coercing text to numeric in AF7102 / R7102C32: 'NaN'”
# Warning message:
# “Coercing text to numeric in AG7102 / R7102C33: 'NaN'”
# Warning message:
# “Coercing text to numeric in AH7102 / R7102C34: 'NaN'”
# Warning message:
# “Coercing text to numeric in AI7102 / R7102C35: 'NaN'”
# Warning message:
# “Coercing text to numeric in AJ7102 / R7102C36: 'NaN'”
# Warning message:
# “Coercing text to numeric in AK7102 / R7102C37: 'NaN'”
# Warning message:
# “Coercing text to numeric in AL7102 / R7102C38: 'NaN'”
# Warning message:
# “Coercing text to numeric in C7103 / R7103C3: 'NaN'”
# Warning message:
# “Coercing text to numeric in D7103 / R7103C4: 'NaN'”
# Warning message:
# “Coercing text to numeric in E7103 / R7103C5: 'NaN'”
# Warning message:
# “Coercing text to numeric in F7103 / R7103C6: 'NaN'”
# Warning message:
# “Coercing text to numeric in G7103 / R7103C7: 'NaN'”
# Warning message:
# “Coercing text to numeric in H7103 / R7103C8: 'NaN'”
# Warning message:
# “Coercing text to numeric in I7103 / R7103C9: 'NaN'”
# Warning message:
# “Coercing text to numeric in K7103 / R7103C11: 'NaN'”
# Warning message:
# “Coercing text to numeric in L7103 / R7103C12: 'NaN'”
# Warning message:
# “Coercing text to numeric in N7103 / R7103C14: 'NaN'”
# Warning message:
# “Coercing text to numeric in P7103 / R7103C16: 'NaN'”
# Warning message:
# “Coercing text to numeric in Q7103 / R7103C17: 'NaN'”
# Warning message:
# “Coercing text to numeric in R7103 / R7103C18: 'NaN'”
# Warning message:
# “Coercing text to numeric in S7103 / R7103C19: 'NaN'”
# Warning message:
# “Coercing text to numeric in T7103 / R7103C20: 'NaN'”
# Warning message:
# “Coercing text to numeric in U7103 / R7103C21: 'NaN'”
# Warning message:
# “Coercing text to numeric in W7103 / R7103C23: 'NaN'”
# Warning message:
# “Coercing text to numeric in X7103 / R7103C24: 'NaN'”
# Warning message:
# “Coercing text to numeric in Y7103 / R7103C25: 'NaN'”
# Warning message:
# “Coercing text to numeric in Z7103 / R7103C26: 'NaN'”
# Warning message:
# “Coercing text to numeric in AA7103 / R7103C27: 'NaN'”
# Warning message:
# “Coercing text to numeric in AC7103 / R7103C29: 'NaN'”
# Warning message:
# “Coercing text to numeric in AD7103 / R7103C30: 'NaN'”
# Warning message:
# “Coercing text to numeric in AE7103 / R7103C31: 'NaN'”
# Warning message:
# “Coercing text to numeric in AF7103 / R7103C32: 'NaN'”
# Warning message:
# “Coercing text to numeric in AG7103 / R7103C33: 'NaN'”
# Warning message:
# “Coercing text to numeric in AH7103 / R7103C34: 'NaN'”
# Warning message:
# “Coercing text to numeric in AI7103 / R7103C35: 'NaN'”
# Warning message:
# “Coercing text to numeric in AJ7103 / R7103C36: 'NaN'”
# Warning message:
# “Coercing text to numeric in AK7103 / R7103C37: 'NaN'”
# Warning message:
# “Coercing text to numeric in AL7103 / R7103C38: 'NaN'”
# Warning message:
# “Coercing text to numeric in D7104 / R7104C4: 'NaN'”
# Warning message:
# “Coercing text to numeric in E7104 / R7104C5: 'NaN'”
# Warning message:
# “Coercing text to numeric in H7104 / R7104C8: 'NaN'”
# Warning message:
# “Coercing text to numeric in I7104 / R7104C9: 'NaN'”
# Warning message:
# “Coercing text to numeric in M7104 / R7104C13: 'NaN'”
# Warning message:
# “Coercing text to numeric in N7104 / R7104C14: 'NaN'”
# Warning message:
# “Coercing text to numeric in O7104 / R7104C15: 'NaN'”
# Warning message:
# “Coercing text to numeric in R7104 / R7104C18: 'NaN'”
# Warning message:
# “Coercing text to numeric in S7104 / R7104C19: 'NaN'”
# Warning message:
# “Coercing text to numeric in U7104 / R7104C21: 'NaN'”
# Warning message:
# “Coercing text to numeric in W7104 / R7104C23: 'NaN'”
# Warning message:
# “Coercing text to numeric in X7104 / R7104C24: 'NaN'”
# Warning message:
# “Coercing text to numeric in Y7104 / R7104C25: 'NaN'”
# Warning message:
# “Coercing text to numeric in Z7104 / R7104C26: 'NaN'”
# Warning message:
# “Coercing text to numeric in AA7104 / R7104C27: 'NaN'”
# Warning message:
# “Coercing text to numeric in AC7104 / R7104C29: 'NaN'”
# Warning message:
# “Coercing text to numeric in AD7104 / R7104C30: 'NaN'”
# Warning message:
# “Coercing text to numeric in AE7104 / R7104C31: 'NaN'”
# Warning message:
# “Coercing text to numeric in AF7104 / R7104C32: 'NaN'”
# Warning message:
# “Coercing text to numeric in AG7104 / R7104C33: 'NaN'”
# Warning message:
# “Coercing text to numeric in AH7104 / R7104C34: 'NaN'”
# Warning message:
# “Coercing text to numeric in AI7104 / R7104C35: 'NaN'”
# Warning message:
# “Coercing text to numeric in AJ7104 / R7104C36: 'NaN'”
# Warning message:
# “Coercing text to numeric in AK7104 / R7104C37: 'NaN'”
# Warning message:
# “Coercing text to numeric in AL7104 / R7104C38: 'NaN'”

# %%
head(proteome_df)
# Out:
#   Protein                     Unique_Peptides Control_R1 Control_R2 Control_R3
# 1 P00761                      13              46631776   51326464   63449032
# 2 P60709                      44              14898485   14393858   18238848
# 3 P0C0S8;Q96KK5;Q99878;Q9BTM1 11               1977650    2275874    7578563
# 4 P23527                      19               1365104    1798281    5384082
# 5 P68104                      51              12752274   13042510   11823310
# 6 P06733                      54               8854008    8850713   10123283
#   Control_R4 Control_R5 Control_R6 CEV_R1   CEV_R2   ⋯ PFAS.CEV_R3 PFAS.CEV_R4
# 1 46508708   32194210   23975652   50760076 39610572 ⋯ 78471912    61208496
# 2 18135594   16799740   17023620   14949095 15522869 ⋯ 23687454    21942680
# 3 14216659    8436507   10723020    1744173  3018039 ⋯ 42397020    41915100
# 4 10863599    6436632    7903236    1547090  2131009 ⋯ 25425400    28165144
# 5 11414176   11093480   10846471   12069089 12141256 ⋯ 12803181    10858694
# 6  8877717    8250112    8561273    8166417  9454755 ⋯ 12480849    11187431
#   PFAS.CEV_R5 PFAS.CEV_R6 PFAS.PEV_R1 PFAS.PEV_R2 PFAS.PEV_R3 PFAS.PEV_R4
# 1 65192580    63247004    49543192    62553512    69856432    92588176
# 2 25449002    20706812    22377822    20689196    20683342    23522216
# 3 63571952    34687048    14175319    12150578    26680958    43462264
# 4 37935572    27360386     8919584    10832857    19775876    29996800
# 5 11959423    10805138    13487166    12406781    12351198    10652401
# 6 12152479     9926687    12584716     9863353    10702597    13051212
#   PFAS.PEV_R5 PFAS.PEV_R6
# 1 69703720    87109000
# 2 22659790    22152380
# 3 49627204    48483936
# 4 34656756    40720276
# 5 10221360    11634231
# 6 11816466    10026787

# %%
longer_proteome_df = proteome_df %>%
    pivot_longer(cols = 3:38, names_to = "ID", values_to = "Value") %>%
   # mutate(Treatment = ID) %>%
    separate(ID, c('Treatment', NA), sep = "_", remove = FALSE)

head(longer_proteome_df)
# Out:
#   Protein Unique_Peptides ID         Treatment Value
# 1 P00761  13              Control_R1 Control   46631776
# 2 P00761  13              Control_R2 Control   51326464
# 3 P00761  13              Control_R3 Control   63449032
# 4 P00761  13              Control_R4 Control   46508708
# 5 P00761  13              Control_R5 Control   32194210
# 6 P00761  13              Control_R6 Control   23975652

# %%
# intial number of proteins prior to filtering
length(unique(proteome_df$Protein))
# Out:
# [1] 7103

# %% [markdown]
# # 1. Peptide Normalization
# Normalize to total amount of peptide per sample: sum the abundance values for each sample, then calculate the median value across all of the summed abundance values, and calculate the ratio

# %%
normalized_df = longer_proteome_df %>%
    group_by(ID) %>%
    #removing missing data
    drop_na() %>%
    mutate(Summed_Value = sum(Value)) %>%
    #calculating median across all samples but still within each set
    ungroup() %>%
    mutate(Median_of_Sum = median(Summed_Value), Norm_Factor = Summed_Value/ Median_of_Sum, 
           Norm_Value = Value/Norm_Factor) %>%
    select(-c("Summed_Value", "Median_of_Sum", "Norm_Factor"))

head(normalized_df)
# Out:
#   Protein Unique_Peptides ID         Treatment Value    Norm_Value
# 1 P00761  13              Control_R1 Control   46631776 48817716
# 2 P00761  13              Control_R2 Control   51326464 54279744
# 3 P00761  13              Control_R3 Control   63449032 63449032
# 4 P00761  13              Control_R4 Control   46508708 46728346
# 5 P00761  13              Control_R5 Control   32194210 34552783
# 6 P00761  13              Control_R6 Control   23975652 25655376

# %% [markdown]
# # 2. Detection Filter - Round 1
# Round 1 - Unable to replicate the 1% peptide/ 5% protein FDR, so we'll just retain proteins that were identified by at least 2 peptides.

# %%
# only keeping proteins > 2 unique proteins
detection_filter_1_df = longer_proteome_df %>%
    filter(Unique_Peptides > 2)

head(detection_filter_1_df)

length(unique(detection_filter_1_df$Protein))
# Out:
#   Protein Unique_Peptides ID         Treatment Value
# 1 P00761  13              Control_R1 Control   46631776
# 2 P00761  13              Control_R2 Control   51326464
# 3 P00761  13              Control_R3 Control   63449032
# 4 P00761  13              Control_R4 Control   46508708
# 5 P00761  13              Control_R5 Control   32194210
# 6 P00761  13              Control_R6 Control   23975652
# [1] 6727

# %% [markdown]
# # 3. Detection Filter - Round 2
# Round 2 - Filter rows based on valid values: 50 % valid in each treatment group (i.e. proteins with values observed in fewer than 50% of replicates (here, 3 reps) in at least 1 condition were eliminated from the dataset)

# %%
protein_presence_df = detection_filter_1_df %>%
    # creating 2 count cols: 1st for non-missing data, 2nd for all data
    mutate(data_count = ifelse(is.na(Value), 0, 1), all_count = 1) %>%
    group_by(Protein, Treatment) %>%
    summarize(Protein_Presence = sum(data_count)/ sum(all_count) * 100) %>%
    filter(Protein_Presence < 50) %>%
    arrange(Protein_Presence) 

head(protein_presence_df)

# getting the proteins in the entire set that will be removed
removed_proteins_df = protein_presence_df %>%
    ungroup() %>%
    select(-Protein_Presence) %>% 
    unique()

# number of proteins removed from each set for the 2nd detection filter
removed_proteins_df %>%
    summarize(`Removed Proteins` = length(unique(Protein)))
# Out:
# `summarise()` has grouped output by 'Protein'. You can override using the
# `.groups` argument.
#   Protein       Treatment Protein_Presence
# 1 A3EZ82;Q6E0U4 PFAS      0
# 2 A3EZ82;Q6E0U4 PFAS.CEV  0
# 3 A3EZ82;Q6E0U4 PFAS.PEV  0
# 4 O00762        PFAS      0
# 5 O00762        PFAS.PEV  0
# 6 O14682        PFAS      0
#   Removed Proteins
# 1 129

# %%
# removing those 129 proteins from the entire dataset 
# finding proteins that exist only in the proteome_df but not the removed proteins_df
detection_filter_2_df = anti_join(detection_filter_1_df, removed_proteins_df)
head(detection_filter_2_df)

# number of proteins kept
detection_filter_2_df %>%
    group_by(Treatment) %>%
    summarize(`Kept Proteins` = length(unique(Protein)))
# Out:
# Joining with `by = join_by(Protein, Treatment)`
#   Protein Unique_Peptides ID         Treatment Value
# 1 P00761  13              Control_R1 Control   46631776
# 2 P00761  13              Control_R2 Control   51326464
# 3 P00761  13              Control_R3 Control   63449032
# 4 P00761  13              Control_R4 Control   46508708
# 5 P00761  13              Control_R5 Control   32194210
# 6 P00761  13              Control_R6 Control   23975652
#   Treatment Kept Proteins
# 1 CEV       6699
# 2 Control   6694
# 3 PEV       6701
# 4 PFAS      6659
# 5 PFAS.CEV  6633
# 6 PFAS.PEV  6643

# %% [markdown]
# # 4. QRILC Imputation
# QRILC replaces data with left-censored data from a Gaussian distribution.

# %%
# adding in normalized values to the filtered df
# left join returns all the records from the first table along with matching records from the second
preimputed_df = left_join(detection_filter_2_df, normalized_df) %>% 
                       select(-Unique_Peptides)

head(preimputed_df)
# Out:
# Joining with `by = join_by(Protein, Unique_Peptides, ID, Treatment, Value)`
#   Protein ID         Treatment Value    Norm_Value
# 1 P00761  Control_R1 Control   46631776 48817716
# 2 P00761  Control_R2 Control   51326464 54279744
# 3 P00761  Control_R3 Control   63449032 63449032
# 4 P00761  Control_R4 Control   46508708 46728346
# 5 P00761  Control_R5 Control   32194210 34552783
# 6 P00761  Control_R6 Control   23975652 25655376

# %%
# QRILC
QRILC_imputation = function(dataset){
    # """
    # Creating a quantile normalization function to normalize each sample.
    # :param (input): exposed and unexposed (vehicle) dfs
    # :output: 1 quantile normalized df
    # """
    wider_dataset = dataset %>%
        select(-c("Value", "Treatment")) %>%
        pivot_wider(names_from = Protein, values_from = Norm_Value) 
    
    # normalizing data since that's what the QRILC function wants
    QRILC_prep = wider_dataset[,2:dim(wider_dataset)[2]] %>%
         mutate_all(., function(x) log2(x)) %>%
         as.matrix()

    imputed_QRILC_object = impute.QRILC(QRILC_prep, tune.sigma = 0.1)
    QRILC_log2_df = data.frame(imputed_QRILC_object[1]) 
    
    # converting back the original scale
    QRILC_df = QRILC_log2_df %>%
        mutate_all(., function(x) 2^x - 1)
    
    # adding back in ID col
    QRILC_df = cbind(ID = wider_dataset$ID, QRILC_df)
            
    # adding back in Tx and Set columns
    final_pivoted_column_number = dim(QRILC_df)[2] + 1

    imputed_dataset = inner_join(unique(dataset %>% 
                                  select(ID, Treatment)), QRILC_df) %>%
        pivot_longer(cols = 3:all_of(final_pivoted_column_number), names_to = "Protein", values_to = "Value")

   return(imputed_dataset)
}

# calling fn
imputed_df = QRILC_imputation(preimputed_df)   
                   
head(imputed_df)
# Out:
# Joining with `by = join_by(ID)`
#   ID         Treatment Protein                     Value
# 1 Control_R1 Control   P00761                      48817715
# 2 Control_R1 Control   P60709                      15596874
# 3 Control_R1 Control   P0C0S8.Q96KK5.Q99878.Q9BTM1  2070354
# 4 Control_R1 Control   P23527                       1429094
# 5 Control_R1 Control   P68104                      13350056
# 6 Control_R1 Control   P06733                       9269053

# %% [markdown]
# # 5. PCA
# Using PCA to identify and remove outlier samples.

# %%
# prepping dfs for PCA
pca_prep_df = imputed_df %>%
    select(-Treatment) %>%
    pivot_wider(names_from = Protein, values_from = Value) %>%
    column_to_rownames(var = "ID")

head(pca_prep_df)
# Out:
#            P00761   P60709   P0C0S8.Q96KK5.Q99878.Q9BTM1 P23527   P68104
# Control_R1 48817715 15596874  2070354                     1429094 13350056
# Control_R2 54279743 15222067  2406825                     1901751 13792964
# Control_R3 63449031 18238847  7578562                     5384081 11823309
# Control_R4 46728345 18221239 14283796                    10914901 11468079
# Control_R5 34552782 18030501  9054571                     6908184 11906196
# Control_R6 25655375 18216287 11474269                     8456932 11606369
#            P06733   P68363   P04406  P10809  P08238  ⋯ A8K2U0    Q9HAW4
# Control_R1  9269053 10759692 9587007 6998959 8720277 ⋯ 2461.9600 2259.1018
# Control_R2  9359974 10725033 8590549 6884546 8845121 ⋯  460.4152 1712.1699
# Control_R3 10123282  9479165 9126735 5676130 8681320 ⋯ 1078.8457  922.9499
# Control_R4  8919641  8409056 8193105 6050519 7445616 ⋯  552.3073  558.6850
# Control_R5  8854520 10075132 8093675 6160617 7608202 ⋯  568.8454 1987.8420
# Control_R6  9161071  9246505 7982725 6539705 7898723 ⋯ 8019.0286 2138.4565
#            O14682   Q9NSG2    Q66K64   Q6IQ21    Q5T3U5    Q6PIY7    P30838
# Control_R1 1606.198  889.3676 1487.988  617.2214 1294.4742  988.4019 38.52594
# Control_R2 1981.276 1297.1294 1681.207 1617.0105 1009.5331 1034.7255 41.19862
# Control_R3 1061.671  765.6619 1300.664 1421.1478 2803.9014 1035.4186 29.80152
# Control_R4 1039.775 1449.3656 1315.565  718.3444  222.9229  657.9548 48.54330
# Control_R5 2043.968 1161.7798 1794.740  811.7983 1212.7284 1288.3598 38.88644
# Control_R6 1326.427 2434.8754 1323.687 1016.1433  615.3126 1071.8126 21.63534
#            P48552
# Control_R1 343.9317
# Control_R2 594.9375
# Control_R3 200.9883
# Control_R4 607.2432
# Control_R5 482.2952
# Control_R6 888.8715

# %%
# running PCA
pca = prcomp(pca_prep_df, scale = TRUE)

# viewing scree plots to see how much of the variance was captured in first 2 eigenvectors
options(repr.plot.width=10, repr.plot.height=5) #changing size
fviz_eig(pca, addlabels = TRUE)
# Out:
# plot without title

# %%
# visualizing all data to detect outliers
fviz_pca_ind(pca, 
             repel = TRUE) +
theme(axis.line = element_line(colour = "black"), #making x and y axes black
      legend.text = element_text(size = 8),
      axis.title = element_text(face = "bold", size = rel(1.1))) #changes axis titles
# Out:
# plot without title

# %% [markdown]
# I'll use a formula to detect outliers rather than visual inspection, since there aren't any obvious outliers.
#
# The standard way to detect outliers in genetics is the criterion of being “more than 6 standard deviations away from the mean”. [source](https://privefl.github.io/blog/detecting-outlier-samples-in-pca/)

# %%
outlier_detection = function(pca_df){
    # """
    # Creating a scoring function for to detect PCA sample outliers. 
    # :param (input): PCA df (df)
    # :output: outlier names
    # """
    
    # getting scores
    scores = pca_df$x
    # identifying samples that are > 6 standard deviations away from the mean
    outlier_indices = apply(scores, 2, function(x) which( abs(x - mean(x)) > (6 * sd(x)) )) %>%
        Reduce(union, .)
    # getting sample names
    outliers = rownames(scores)[outlier_indices]
    
    return(outliers)
}

# calling fn
outliers = outlier_detection(pca)

# %%
# number of samples to be removed from this filter
length(outliers)
# Out:
# [1] 0

# %%
# removing those outliers (even though there were none)
`%notin%` <- Negate(`%in%`)

removed_outliers_df = imputed_df %>%
    filter(ID %notin% outliers)

# %%
# creating 1 final df with protiens that passed all filters
final_df = removed_outliers_df

head(final_df)
# Out:
#   ID         Treatment Protein                     Value
# 1 Control_R1 Control   P00761                      48817715
# 2 Control_R1 Control   P60709                      15596874
# 3 Control_R1 Control   P0C0S8.Q96KK5.Q99878.Q9BTM1  2070354
# 4 Control_R1 Control   P23527                       1429094
# 5 Control_R1 Control   P68104                      13350056
# 6 Control_R1 Control   P06733                       9269053

# %%
# final number of proteins for each treatment
final_df %>%
    group_by(Treatment) %>%
    summarize(`Final Number of Proteins` = length(unique(Protein)))
# Out:
#   Treatment Final Number of Proteins
# 1 CEV       6715
# 2 Control   6715
# 3 PEV       6715
# 4 PFAS      6715
# 5 PFAS.CEV  6715
# 6 PFAS.PEV  6715

# %%
# exporting
write.xlsx(final_df, paste0(Output,"/", "Imputed_Proteomics_Data_", cur_date, ".xlsx"), 
           rowNames = FALSE)
